# %%
from pathlib import Path
import pandas as pd
import matplotlib

# %%
csv_path = Path("/home/tiep_nguyen/IndySCC-HPL-Scripts/analysis/output.csv")

current_data = pd.read_csv(csv_path)

# %%
ax=current_data.plot.hist(column=["Gflops"], bins=20,legend=True)
