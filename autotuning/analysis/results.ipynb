# %%
from pathlib import Path
import pickle
import matplotlib.pyplot as plt
import sys
import os
import numpy as np
os.getcwd()
# Out:
# '/home/tiep_nguyen/IndySCC-HPL-Scripts/autotuning'

# %%
print(os.getcwd())
print(str(Path(os.getcwd()).joinpath("src/HPLWrapper").resolve()))
print(str(Path(os.getcwd()).joinpath("src/Optimizer").resolve()))
sys.path.append(str(Path(os.getcwd()).joinpath("src/HPLWrapper").resolve()))
sys.path.append(str(Path(os.getcwd()).joinpath("src/Optimizer").resolve()))
# Out:
# /home/tiep_nguyen/IndySCC-HPL-Scripts/autotuning
# /home/tiep_nguyen/IndySCC-HPL-Scripts/autotuning/src/HPLWrapper
# /home/tiep_nguyen/IndySCC-HPL-Scripts/autotuning/src/Optimizer

# %%
from HPLConfig import HPLConfig
from HPLOptimizer import HPLOptimizer

# %%
MODEL_FOLDER = Path(r"/home/tnguyen668/software/HPL-Scripts/autotuning/results/train_6")

# %%
hpl_optimizer = None

with open(MODEL_FOLDER.joinpath('optimizer.pk1'), 'rb') as file:
    hpl_optimizer=pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 hpl_optimizer = None
# ----> 3 with open(MODEL_FOLDER.joinpath('optimizer.pk1'), 'rb') as file:
#       4     hpl_optimizer=pickle.load(file)
#
# File ~/software/HPL-Scripts/autotuning/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/tnguyen668/software/HPL-Scripts/autotuning/results/train_6/optimizer.pk1'

# %%
data = list(map(lambda x: x*-1,hpl_optimizer.optimizer.yi))

plt.figure(figsize=(8, 5))
plt.plot(range(len(data)), data, marker='o', linestyle='-', color='b', label='Gflops')
plt.plot(np.linspace(0, len(data)-1, len(data)), [max(data)]*len(data), linestyle='--', color='r', label='Max Gflops')
plt.plot(np.linspace(0, len(data)-1, len(data)), [2100] * len(data), color='g', label='Baseline')

plt.title('Glops as training')
plt.xlabel('Run')
plt.ylabel('Gflops')
plt.grid(True)
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()
